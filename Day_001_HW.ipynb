# %% [markdown]
# ## 作業1
#
# 完成 Mean Squared Error 的函式。

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def mean_squared_error(y,yp):
    """
    計算MSE
    Args (y:實際值, yp:預測值)
    
    """
    mse = sum((y-yp)**2)/len(y)
    return mse

def mean_absolute_error(y,yp):
    """
    計算MAE
    Args (y:實際值, yp:預測值)
    
    """
    mae = sum(abs(y-yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

# np.linspace(0, 100, 101)是指 0~100 劃分成 101 個刻度(含頭尾), 所也就是 0, 1, 2,...,100 這 101 個數
# 這時候, x_lin 因為要記錄不只一個數, 因為 np.linspace() 傳回的是一個 Array, 所以 x_lin 就變成 Array 了
x_lin = np.linspace(0,100,101)

# np.random.randn() 就是 numpy.random.randn(), 會隨機傳回標準常態分布的取樣值
# np.random.randn(101) 表示取樣了101次, 型態是 Array, 所以其他 + 與 * 的部分都是 Array 的加與乘, 一行就計算了101筆資料
# 所以最後的結果 y, 也是一個長度 101 的 Array
y = (x_lin + np.random.randn(101) * 5) * w + b

# b. : b 就是 blue, 點(.) 就是最小單位的形狀
plt.plot(x_lin, y, 'b.', label='data points')   #label will be displayed in the legend
plt.title("Assume we have data points")
plt.legend(loc=2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin,  y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
# 上面的 'b.' 是藍色點狀, 下面的 'r-' 是紅色線狀, label 是圖示上的名稱
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show;

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
print("The Mean Sqaured Error is %.3f" %(MSE))
MAE = mean_absolute_error(y, y_hat)
print("The Absolute Error is %.3f" %(MAE))
# Out:
# The Mean Sqaured Error is 195.947
# The Absolute Error is 10.705

# %% [markdown]
# ## 作業2
#
# ### Tesla stock data from 2010 to 2020
#
# **1. 你選的這組資料為何重要**
# 這陣子Tesla股價瘋狂上升加上他們擁有的科技趨勢，可以購過了解Tesla股市漲跌的資料去預測接下來的股市變化，就能夠找到時機點投資。
#
# **2. 資料從何而來**
# Timo Bozsolik所提供，網路爬蟲
#
# **3. 蒐集而來的資料型態為何**
# 結構化:表格
#
# **4.這組資料想解決的問題如何評估**
# 股市的漲跌。highest/lowest stock price that day, Adusted closing price, Trading volume, Open price

# %% [markdown]
# #### 作業3
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# **1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)**
# 如何提升業績。當我換了一個廣告行銷方式，載客數是否會提高?
#
# **2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)**
# 廣告點擊率、觀看率、conversion rate
#
# **3. 蒐集而來的資料型態為何**
# 結構化:表格
#
# **4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)**
# a/b testing，看載客率是否提升
